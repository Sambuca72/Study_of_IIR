# %%
# %pip install ultralytics

# %%
from pathlib import Path
from ultralytics import YOLO
import os


BASE_DIR = Path(os.getcwd())
DATA_YAML = BASE_DIR / 'dataset.yaml'

# %%
model = YOLO('yolov8n.pt')
model.train(data=str(DATA_YAML), epochs=50, imgsz=1024, batch=16, patience=15,
            lr0=0.01, cos_lr=True, close_mosaic=10, amp=True, device=0, workers=8,
            seed=13, plots=True, save=True, project=str(BASE_DIR / 'runs'), name='hrplanes')
# Out:
# Ultralytics 8.4.51 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla V100-SXM2-32GB, 32494MiB)
# ...

# %%
import matplotlib.pyplot as plt
from PIL import Image

best_model_path = BASE_DIR /'runs'/'hrplanes-26'/'weights'/'best.pt'

if best_model_path.exists():

    trained_model = YOLO(str(best_model_path))

    test_img_path = BASE_DIR /'dataset/test/images'
    
    results = trained_model.predict(
        source=str(test_img_path),
        imgsz=1024,
        conf=0.25,      
        save=True,      
        project=str(BASE_DIR /'runs'),
        name='predictions'
    )
    
    print(f"Предсказания сохранены в папку: {BASE_DIR /'runs'/'predictions'}")
else:
    print(f"Файл весов не найден по пути: {best_model_path}")
# Out:
# image 1/310 /home/a.stolyarov/Study_of_IIR/AI/dataset/test/images/AMST_039.jpg: 608x1024 17 Planes, 35.7ms
# image 2/310 /home/a.stolyarov/Study_of_IIR/AI/dataset/test/images/AMST_043.jpg: 608x1024 1 Plane, 7.8ms
# image 3/310 /home/a.stolyarov/Study_of_IIR/AI/dataset/test/images/AMST_052.jpg: 608x1024 7 Planes, 7.3ms
# image 4/310 /home/a.stolyarov/Study_of_IIR/AI/dataset/test/images/AMST_055.jpg: 608x1024 3 Planes, 9.6ms
# image 5/310 /home/a.stolyarov/Study_of_IIR/AI/dataset/test/images/AMST_060.jpg: 608x1024 3 Planes, 7.3ms
# image 6/310 /home/a.stolyarov/Study_of_IIR/AI/dataset/test/images/AMST_071.jpg: 608x1024 6 Planes, 6.5ms
# image 7/310 /home/a.stolyarov/Study_of_IIR/AI/dataset/test/images/AMST_072.jpg: 608x1024 15 Planes, 7.4ms
# image 8/310 /home/a.stolyarov/Study_of_IIR/AI/dataset/test/images/CTU_0021.jpg: 608x1024 6 Planes, 6.9ms
# image 9/310 /home/a.stolyarov/Study_of_IIR/AI/dataset/test/images/CTU_0038.jpg: 608x1024 3 Planes, 7.4ms
# ...

# %%
print("Validation:")
val_metrics = trained_model.val() 
print(f"mAP50 (val): {val_metrics.box.map50:.3f}")
print(f"mAP50-95 (val): {val_metrics.box.map:.3f}")
print(f"Precision (val): {val_metrics.box.mp:.3f}")
print(f"Recall (val): {val_metrics.box.mr:.3f}")

print("\nTest:")
test_metrics = trained_model.val(split='test') 
print(f"mAP50 (test): {test_metrics.box.map50:.3f}")
print(f"mAP50-95 (test): {test_metrics.box.map:.3f}")
print(f"Precision (test): {test_metrics.box.mp:.3f}")
print(f"Recall (test): {test_metrics.box.mr:.3f}")
# Out:
# Validation:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 print("Validation:")
# ----> 2 val_metrics = trained_model.val()
#       3 print(f"mAP50 (val): {val_metrics.box.map50:.3f}")
#       4 print(f"mAP50-95 (val): {val_metrics.box.map:.3f}")
#
# NameError: name 'trained_model' is not defined
